# %%
import re as re

import pandas as pd
import numpy as np

from sklearn.manifold import TSNE
from sklearn.manifold import Isomap
from sklearn.cluster import SpectralClustering
from sklearn.preprocessing import MinMaxScaler

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %ls data
# Out:
# Air pollutant.csv
# Dog and Cat food production EIO_LCA new.xlsx
# Dog and Cat food production EIO_LCA.xlsx
# Energy.csv
# GWP.csv
# sector.csv

# %%
airpolu=pd.read_csv("data/Air pollutant.csv")
energy=pd.read_csv("data/Energy.csv")
GWP=pd.read_csv("data/GWP.csv").iloc[:,:4]
sector=pd.read_csv("data/sector.csv")

# %%
def combineSector(df, df_sector):
    def find_number(text):
        num = re.findall(r'[0-9]+',text)
        return " ".join(num)

    def first2(text):
        return text[:2]
    df2 = df.copy()
    ID2 = df2['ID'].map(find_number).map(first2).astype('int64')
    df2.insert(loc=1, column='ID2', value=ID2)
    df_sector=df_sector.merge(df2, on='ID2', how='right')
    return df_sector

def tsneFind2Pinciple(df_sector):

    Principle = TSNE(n_components=2).fit_transform(df_sector.iloc[:,4:])
    Principle=pd.DataFrame(Principle, columns=['P1','P2'])
    new_df=df_sector.iloc[:,:4]
    new_df[['P1','P2']]=Principle
    return new_df

def addCluster(df_sector, df_principle):

    clustering = SpectralClustering(n_clusters=3, assign_labels='discretize',random_state=0).fit(df_principle[['P1','P2']])
    df_principle['cluster']=clustering.labels_
    return df_principle
    
def checkGroupAgg(df, df_sector_cluster, by=['cluster','Sector'], func = ['max','min']):
    df_cluster = pd.concat([df_sector_cluster[by], df.iloc[:,2:]], axis=1)
    return df_cluster.groupby(by).agg(func).style.highlight_max(axis=0)

def groupcount(df_sector_cluster):
    df = df_sector_cluster[['cluster','Sector','ID']].groupby(['cluster','Sector']).agg('count').reset_index(drop=False)
    df.columns=['cluster','Sector','count']
    return df.sort_values(by=['cluster','count'], ascending=False)

def masking0row(df):
    df_data=df.iloc[:,3:]
    mask = (df_data != 0).sum(1)!=0
    print('Drop', len(df[-mask]['Subsector']), 'unrelative subsectors that contain only zero \n',df[-mask]['Subsector'], )
    return df[mask]

def plot_scatter(df_sector_cluster, style="cluster", hue="cluster", size = None, figsize = (5,5), if_ledgend= True):
    plt.figure(figsize=figsize)
    g= sns.scatterplot(data=df_sector_cluster, x="P1", y="P2", style=style, hue=hue, size = size, palette="viridis")
    if if_ledgend:
        plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)
    else:
        plt.legend([],[], frameon=False)
    plt.show()
    
def plot_lm(df_sector_cluster, hue="cluster", figsize = (5,5), if_ledgend= True):
    plt.figure(figsize=figsize)
    g= sns.lmplot(data=df_sector_cluster, x="P1", y="P2", hue=hue, ci=None)
    if if_ledgend:
        plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)
    else:
        plt.legend([],[], frameon=False)
    plt.show()

def plotHeatmap(df):
    # Compute the correlation matrix
    corr = df.iloc[:,2:].corr()
    # Generate a mask for the upper triangle
    mask = np.triu(np.ones_like(corr, dtype=bool))
    # Set up the matplotlib figure
    f, ax = plt.subplots(figsize=(11, 9))
    # Generate a custom diverging colormap
    cmap = sns.diverging_palette(230, 20, as_cmap=True)
    # Draw the heatmap with the mask and correct aspect ratio
    sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
                square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
df = airpolu.merge(GWP.drop(columns=['Total t CO2e']), on=['ID'], how='outer').fillna(0)
df['Subsector_x']=df['Subsector_x'].astype('str') + " OR " + df['Subsector_y'].astype('str')
df= df.drop(columns=['Subsector_y']).rename(columns={"Subsector_x": "Subsector"})
df = df.merge(energy.drop(columns=['Total Energy TJ']), on=['ID'], how='outer').fillna(0)
df['Subsector_x']=df['Subsector_x'].astype('str') + " OR " + df['Subsector_y'].astype('str')
df= df.drop(columns=['Subsector_y']).rename(columns={"Subsector_x": "Subsector"})
df.head(5)
# Out:
#        ID                                          Subsector     CO t  \
# 0  484000  Truck Transport OR Truck transportation OR Tru...  18800.0
# 1  33131A  Aluminum OR Alumina refining and primary alumi...  18800.0
# 2  1111B0  Fresh Wheat, Corn, Rice, And Other Grains OR G...   4730.0
# 3  211000  Unrefined Oil And Gas OR Oil and gas extractio...   3550.0
# 4  1121A0  Cattle Ranches And Feedlots OR Cattle ranching...   2580.0
#
#       NH3 t    NOx t    PM10 t  PM 2.5 t    SO2 t    VOC t  CO2 t CO2e  \
# 0     70.70  10700.0    196.00     445.0    24.10   1470.0   4190000.0
# 1     10.50    261.0    125.00     477.0  2890.00    260.0    226000.0
# 2  22500.00   4420.0  43200.00   11200.0    12.50   3960.0   6080000.0
# 3      1.15   3900.0      6.86      98.7   306.00  11400.0   1200000.0
# 4  18300.00   2770.0    275.00     271.0     6.37    252.0   1250000.0
#
#    Coal TJ  Nat Gas TJ  Petrol  TJ  Bio/Waste TJ  NonFossElec TJ
# 0      0.0         0.0     56200.0           0.0           539.0
# 1      0.0      4270.0       135.0         400.0         11200.0
# 2      0.0     10400.0     80500.0           0.0         14800.0
# 3      0.0     20800.0      2170.0           0.0          2500.0
# 4      0.0      1240.0     17300.0           0.0          3580.0

# %%
scaler = MinMaxScaler(feature_range=(0,10))
df.iloc[:,2:] =scaler.fit_transform(df.iloc[:,2:])
df = masking0row(df).reset_index(drop=True)
print(df.shape)
# Out:
# Drop 39 unrelative subsectors that contain only zero
#  306                                 Ambulances OR 0 OR 0
# 334                      Outpatient Healthcare OR 0 OR 0
# 337             Individual And Family Services OR 0 OR 0
# 342      Nursing And Community Care Facilities OR 0 OR 0
# 344                       Medical Laboratories OR 0 OR 0
# 347    Healthcare Practitioners (Except Physicians An...
# 350    Residential Mental Retardation, Mental Health,...
# 353               Other Residential Structures OR 0 OR 0
# 356                                 Physicians OR 0 OR 0
# 358                                   Dentists OR 0 OR 0
# 362    Commercial Structures, Including Farm Structur...
# 363    Elementary And Secondary Schools OR Elementary...
# 364    Federal Government (Defense) OR General Federa...
# 365    Federal Government (Nondefense) OR General Fed...
# 366    Funerary Services OR Death care services OR De...
# 367    Gambling Establishments (Except Casino Hotels)...
# 368                      Health Care Buildings OR 0 OR 0
# 369             Highways, Streets, And Bridges OR 0 OR 0
# 370    Home Healthcare OR Home health care services O...
# 372    Household Employees OR Private households OR P...
# 373                                    Housing OR 0 OR 0
# 374                    Manufacturing Buildings OR 0 OR 0
# 376                          Multifamily Homes OR 0 OR 0
# 377    Museums, Historical Sites, Zoos, And Parks OR ...
# 378    Noncomparable Imports OR Noncomparable Imports...
# 379            Other Nonresidential Structures OR 0 OR 0
# 380    Religious Organizations OR Religious organizat...
# 381    Rest Of The World Adjustment OR ROW Adjustment...
# 382           Schools And Vocational Buildings OR 0 OR 0
# 383                        Single-Family Homes OR 0 OR 0
# 385    Used And Secondhand Goods OR Used and Secondha...
# 386     Utilities Buildings And Infrastructure OR 0 OR 0
# 497    0 OR Hunting and trapping OR Hunting and trapping
# 498    0 OR Nonresidential commercial and health care...
# 499    0 OR Nonresidential manufacturing structures O...
# 500    0 OR Other nonresidential structures OR Other ...
# 501    0 OR Owner-Occupied Dwellings OR Owner-Occupie...
# 502    0 OR Residential permanent site single- and mu...
# 503                                  0 OR Scrap OR Scrap
# Name: Subsector, dtype: object
# (465, 15)

# %%
# sns.pairplot(df.iloc[:,2:])

# %%
plotHeatmap(df)

# %%
sector = combineSector(df, df_sector=sector)
principle = tsneFind2Pinciple(sector)
sector_cluster= addCluster(df_sector=sector, df_principle=principle)
plot_scatter(sector_cluster, style='cluster', hue='cluster', if_ledgend= True)

# %%
plot_lm(sector_cluster, hue="cluster", if_ledgend= True)

# %%
for col in df.columns[2:]:
    print(col)
    col0mask = df[col]!=0
    plot_scatter(sector_cluster[col0mask], hue=np.log(df[col][col0mask]), figsize = (5,5), if_ledgend = False)
# Out:
# CO t
# NH3 t
# NOx t
# PM10 t
# PM 2.5 t
# SO2 t
# VOC t
# CO2 t CO2e
# Coal TJ
# Nat Gas TJ
# Petrol  TJ
# Bio/Waste TJ
# NonFossElec TJ

# %%
checkGroupAgg(df = energy, df_sector_cluster = sector_cluster,
             by=['cluster'], func = ['max','min'])
# Out:
# <style  type="text/css" >
# #T_0e363_row0_col0,#T_0e363_row0_col2,#T_0e363_row0_col3,#T_0e363_row0_col4,#T_0e363_row0_col8,#T_0e363_row0_col9,#T_0e363_row0_col10,#T_0e363_row1_col3,#T_0e363_row1_col6,#T_0e363_row1_col7,#T_0e363_row1_col9,#T_0e363_row2_col1,#T_0e363_row2_col3,#T_0e363_row2_col5,#T_0e363_row2_col9,#T_0e363_row2_col11{
#             background-color:  yellow;
#         }</style><table id="T_0e363_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" colspan="2">Total Energy TJ</th>        <th class="col_heading level0 col2" colspan="2">Coal TJ</th>        <th class="col_heading level0 col4" colspan="2">Nat Gas TJ</th>        <th class="col_heading level0 col6" colspan="2">Petrol  TJ</th>        <th class="col_heading level0 col8" colspan="2">Bio/Waste TJ</th>        <th class="col_heading level0 col10" colspan="2">NonFossElec TJ</th>    </tr>    <tr>        <th class="blank level1" ></th>        <th class="col_heading level1 col0" >max</th>        <th class="col_heading level1 col1" >min</th>        <th class="col_heading level1 col2" >max</th>        <th class="col_heading level1 col3" >min</th>        <th class="col_heading level1 col4" >max</th>        <th class="col_heading level1 col5" >min</th>        <th class="col_heading level1 col6" >max</th>        <th class="col_heading level1 col7" >min</th>        <th class="col_heading level1 col8" >max</th>        <th class="col_heading level1 col9" >min</th>        <th class="col_heading level1 col10" >max</th>        <th class="col_heading level1 col11" >min</th>    </tr>    <tr>        <th class="index_name level0" >cluster</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0e363_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_0e363_row0_col0" class="data row0 col0" >319000.000000</td>
#                         <td id="T_0e363_row0_col1" class="data row0 col1" >0.000000</td>
#                         <td id="T_0e363_row0_col2" class="data row0 col2" >232000.000000</td>
#                         <td id="T_0e363_row0_col3" class="data row0 col3" >0.000000</td>
#                         <td id="T_0e363_row0_col4" class="data row0 col4" >137000.000000</td>
#                         <td id="T_0e363_row0_col5" class="data row0 col5" >0.000000</td>
#                         <td id="T_0e363_row0_col6" class="data row0 col6" >30800.000000</td>
#                         <td id="T_0e363_row0_col7" class="data row0 col7" >0.000000</td>
#                         <td id="T_0e363_row0_col8" class="data row0 col8" >18100.000000</td>
#                         <td id="T_0e363_row0_col9" class="data row0 col9" >0.000000</td>
#                         <td id="T_0e363_row0_col10" class="data row0 col10" >42300.000000</td>
#                         <td id="T_0e363_row0_col11" class="data row0 col11" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_0e363_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_0e363_row1_col0" class="data row1 col0" >106000.000000</td>
#                         <td id="T_0e363_row1_col1" class="data row1 col1" >152.000000</td>
#                         <td id="T_0e363_row1_col2" class="data row1 col2" >26000.000000</td>
#                         <td id="T_0e363_row1_col3" class="data row1 col3" >0.000000</td>
#                         <td id="T_0e363_row1_col4" class="data row1 col4" >13100.000000</td>
#                         <td id="T_0e363_row1_col5" class="data row1 col5" >0.000000</td>
#                         <td id="T_0e363_row1_col6" class="data row1 col6" >80500.000000</td>
#                         <td id="T_0e363_row1_col7" class="data row1 col7" >0.704000</td>
#                         <td id="T_0e363_row1_col8" class="data row1 col8" >2150.000000</td>
#                         <td id="T_0e363_row1_col9" class="data row1 col9" >0.000000</td>
#                         <td id="T_0e363_row1_col10" class="data row1 col10" >14800.000000</td>
#                         <td id="T_0e363_row1_col11" class="data row1 col11" >32.500000</td>
#             </tr>
#             <tr>
#                         <th id="T_0e363_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_0e363_row2_col0" class="data row2 col0" >412.000000</td>
#                         <td id="T_0e363_row2_col1" class="data row2 col1" >394.000000</td>
#                         <td id="T_0e363_row2_col2" class="data row2 col2" >0.000000</td>
#                         <td id="T_0e363_row2_col3" class="data row2 col3" >0.000000</td>
#                         <td id="T_0e363_row2_col4" class="data row2 col4" >141.000000</td>
#                         <td id="T_0e363_row2_col5" class="data row2 col5" >10.800000</td>
#                         <td id="T_0e363_row2_col6" class="data row2 col6" >238.000000</td>
#                         <td id="T_0e363_row2_col7" class="data row2 col7" >0.000000</td>
#                         <td id="T_0e363_row2_col8" class="data row2 col8" >6.720000</td>
#                         <td id="T_0e363_row2_col9" class="data row2 col9" >0.000000</td>
#                         <td id="T_0e363_row2_col10" class="data row2 col10" >264.000000</td>
#                         <td id="T_0e363_row2_col11" class="data row2 col11" >145.000000</td>
#             </tr>
#     </tbody></table>

# %%
checkGroupAgg(df = energy, df_sector_cluster = sector_cluster,
             by=['cluster','Sector'], func = ['max','min'])
# Out:
# <style  type="text/css" >
# #T_58d01_row9_col3,#T_58d01_row10_col4,#T_58d01_row10_col10,#T_58d01_row16_col0,#T_58d01_row16_col2,#T_58d01_row16_col8,#T_58d01_row19_col5,#T_58d01_row19_col6,#T_58d01_row19_col11,#T_58d01_row21_col1,#T_58d01_row21_col7,#T_58d01_row23_col9{
#             background-color:  yellow;
#         }</style><table id="T_58d01_" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" colspan="2">Total Energy TJ</th>        <th class="col_heading level0 col2" colspan="2">Coal TJ</th>        <th class="col_heading level0 col4" colspan="2">Nat Gas TJ</th>        <th class="col_heading level0 col6" colspan="2">Petrol  TJ</th>        <th class="col_heading level0 col8" colspan="2">Bio/Waste TJ</th>        <th class="col_heading level0 col10" colspan="2">NonFossElec TJ</th>    </tr>    <tr>        <th class="blank" ></th>        <th class="blank level1" ></th>        <th class="col_heading level1 col0" >max</th>        <th class="col_heading level1 col1" >min</th>        <th class="col_heading level1 col2" >max</th>        <th class="col_heading level1 col3" >min</th>        <th class="col_heading level1 col4" >max</th>        <th class="col_heading level1 col5" >min</th>        <th class="col_heading level1 col6" >max</th>        <th class="col_heading level1 col7" >min</th>        <th class="col_heading level1 col8" >max</th>        <th class="col_heading level1 col9" >min</th>        <th class="col_heading level1 col10" >max</th>        <th class="col_heading level1 col11" >min</th>    </tr>    <tr>        <th class="index_name level0" >cluster</th>        <th class="index_name level1" >Sector</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_58d01_level0_row0" class="row_heading level0 row0" rowspan="19">0</th>
#                         <th id="T_58d01_level1_row0" class="row_heading level1 row0" >Accommodation and Food Services</th>
#                         <td id="T_58d01_row0_col0" class="data row0 col0" >354.000000</td>
#                         <td id="T_58d01_row0_col1" class="data row0 col1" >0.547000</td>
#                         <td id="T_58d01_row0_col2" class="data row0 col2" >57.200000</td>
#                         <td id="T_58d01_row0_col3" class="data row0 col3" >0.000000</td>
#                         <td id="T_58d01_row0_col4" class="data row0 col4" >201.000000</td>
#                         <td id="T_58d01_row0_col5" class="data row0 col5" >0.278000</td>
#                         <td id="T_58d01_row0_col6" class="data row0 col6" >41.700000</td>
#                         <td id="T_58d01_row0_col7" class="data row0 col7" >0.010000</td>
#                         <td id="T_58d01_row0_col8" class="data row0 col8" >3.390000</td>
#                         <td id="T_58d01_row0_col9" class="data row0 col9" >0.018000</td>
#                         <td id="T_58d01_row0_col10" class="data row0 col10" >50.400000</td>
#                         <td id="T_58d01_row0_col11" class="data row0 col11" >0.241000</td>
#             </tr>
#             <tr>
#                                 <th id="T_58d01_level1_row1" class="row_heading level1 row1" >Administrative and Support and Waste Management and Remediation Services</th>
#                         <td id="T_58d01_row1_col0" class="data row1 col0" >37800.000000</td>
#                         <td id="T_58d01_row1_col1" class="data row1 col1" >70.600000</td>
#                         <td id="T_58d01_row1_col2" class="data row1 col2" >69.300000</td>
#                         <td id="T_58d01_row1_col3" class="data row1 col3" >0.000000</td>
#                         <td id="T_58d01_row1_col4" class="data row1 col4" >3810.000000</td>
#                         <td id="T_58d01_row1_col5" class="data row1 col5" >3.520000</td>
#                         <td id="T_58d01_row1_col6" class="data row1 col6" >28400.000000</td>
#                         <td id="T_58d01_row1_col7" class="data row1 col7" >20.100000</td>
#                         <td id="T_58d01_row1_col8" class="data row1 col8" >230.000000</td>
#                         <td id="T_58d01_row1_col9" class="data row1 col9" >0.000000</td>
#                         <td id="T_58d01_row1_col10" class="data row1 col10" >5610.000000</td>
#                         <td id="T_58d01_row1_col11" class="data row1 col11" >11.600000</td>
#             </tr>
#             <tr>
#                                 <th id="T_58d01_level1_row2" class="row_heading level1 row2" >Agriculture, Forestry, Fishing and Hunting</th>
#                         <td id="T_58d01_row2_col0" class="data row2 col0" >25500.000000</td>
#                         <td id="T_58d01_row2_col1" class="data row2 col1" >0.017000</td>
#                         <td id="T_58d01_row2_col2" class="data row2 col2" >111.000000</td>
#                         <td id="T_58d01_row2_col3" class="data row2 col3" >0.000000</td>
#                         <td id="T_58d01_row2_col4" class="data row2 col4" >20800.000000</td>
#                         <td id="T_58d01_row2_col5" class="data row2 col5" >0.000000</td>
#                         <td id="T_58d01_row2_col6" class="data row2 col6" >5160.000000</td>
#                         <td id="T_58d01_row2_col7" class="data row2 col7" >0.000000</td>
#                         <td id="T_58d01_row2_col8" class="data row2 col8" >1350.000000</td>
#                         <td id="T_58d01_row2_col9" class="data row2 col9" >0.000000</td>
#                         <td id="T_58d01_row2_col10" class="data row2 col10" >11200.000000</td>
#                         <td id="T_58d01_row2_col11" class="data row2 col11" >0.000000</td>
#             </tr>
#             <tr>
#                                 <th id="T_58d01_level1_row3" class="row_heading level1 row3" >Arts, Entertainment, and Recreation</th>
#                         <td id="T_58d01_row3_col0" class="data row3 col0" >5760.000000</td>
#                         <td id="T_58d01_row3_col1" class="data row3 col1" >0.000000</td>
#                         <td id="T_58d01_row3_col2" class="data row3 col2" >303.000000</td>
#                         <td id="T_58d01_row3_col3" class="data row3 col3" >0.000000</td>
#                         <td id="T_58d01_row3_col4" class="data row3 col4" >833.000000</td>
#                         <td id="T_58d01_row3_col5" class="data row3 col5" >0.000000</td>
#                         <td id="T_58d01_row3_col6" class="data row3 col6" >882.000000</td>
#                         <td id="T_58d01_row3_col7" class="data row3 col7" >0.000000</td>
#                         <td id="T_58d01_row3_col8" class="data row3 col8" >23.700000</td>
#                         <td id="T_58d01_row3_col9" class="data row3 col9" >0.000000</td>
#                         <td id="T_58d01_row3_col10" class="data row3 col10" >4520.000000</td>
#                         <td id="T_58d01_row3_col11" class="data row3 col11" >0.000000</td>
#             </tr>
#             <tr>
#                                 <th id="T_58d01_level1_row4" class="row_heading level1 row4" >Construction</th>
#                         <td id="T_58d01_row4_col0" class="data row4 col0" >4750.000000</td>
#                         <td id="T_58d01_row4_col1" class="data row4 col1" >0.000000</td>
#                         <td id="T_58d01_row4_col2" class="data row4 col2" >0.000000</td>
#                         <td id="T_58d01_row4_col3" class="data row4 col3" >0.000000</td>
#                         <td id="T_58d01_row4_col4" class="data row4 col4" >411.000000</td>
#                         <td id="T_58d01_row4_col5" class="data row4 col5" >0.000000</td>
#                         <td id="T_58d01_row

# %%
groupcount(sector_cluster)
# Out:
#     cluster                                             Sector  count
# 24        2                    Accommodation and Food Services      2
# 20        1                                      Manufacturing      4
# 19        1         Agriculture, Forestry, Fishing and Hunting      3
# 22        1      Other Services (except Public Administration)      2
# 21        1      Mining, Quarrying, and Oil and Gas Extraction      1
# 23        1   Professional, Scientific, and Technical Services      1
# 10        0                                      Manufacturing    307
# 2         0         Agriculture, Forestry, Fishing and Hunting     19
# 8         0                                        Information     19
# 13        0   Professional, Scientific, and Technical Services     13
# 11        0      Mining, Quarrying, and Oil and Gas Extraction     11
# 3         0                Arts, Entertainment, and Recreation     10
# 16        0                     Transportation and Warehousing     10
# 1         0  Administrative and Support and Waste Managemen...      9
# 12        0      Other Services (except Public Administration)      9
# 6         0                              Finance and Insurance      8
# 7         0                  Health Care and Social Assistance      7
# 14        0                 Real Estate and Rental and Leasing      7
# 0         0                    Accommodation and Food Services      5
# 4         0                                       Construction      3
# 15        0                                       Retail Trade      3
# 17        0                                          Utilities      3
# 5         0                               Educational Services      2
# 9         0            Management of Companies and Enterprises      1
# 18        0                                    Wholesale Trade      1
