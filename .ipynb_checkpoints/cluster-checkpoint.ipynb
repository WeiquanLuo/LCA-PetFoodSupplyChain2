# %%
import re as re

import pandas as pd
import numpy as np

from sklearn.manifold import TSNE
from sklearn.manifold import Isomap
from sklearn.cluster import SpectralClustering, OPTICS, DBSCAN
from sklearn.preprocessing import MinMaxScaler

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %ls data
# Out:
# Air pollutant.csv  Energy.csv         GWP.csv            sector.csv

# %%
airpolu=pd.read_csv("data/Air pollutant.csv")
energy=pd.read_csv("data/Energy.csv")
GWP=pd.read_csv("data/GWP.csv")
sector=pd.read_csv("data/sector.csv")

# %%
print(energy.shape)
print(energy.columns)
# Out:
# (428, 8)
# Index(['ID', 'Subsector', 'Total Energy TJ', 'Coal TJ', 'Nat Gas TJ',
#        'Petrol  TJ', 'Bio_Waste TJ', 'NonFossElec TJ'],
#       dtype='object')

# %%
print(GWP.shape)
print(GWP.columns)
# Out:
# (428, 7)
# Index(['ID', 'Subsector', 'Total t CO2e', 'CO2 t CO2e', 'CH4 t CO2e',
#        'N2O t CO2e', 'Other GHGs t CO2e'],
#       dtype='object')

# %%
def combineSector(df, df_sector):
    def find_number(text):
        num = re.findall(r'[0-9]+',text)
        return " ".join(num)

    def first2(text):
        return text[:2]
    df2 = df.copy()
    ID2 = df2['ID'].map(find_number).map(first2).astype('int64')
    df2.insert(loc=1, column='ID2', value=ID2)
    df_sector=df_sector.merge(df2, on='ID2', how='right')
    return df_sector

def tsneFind2Pinciple(df_sector):

    Principle = TSNE(n_components=2, random_state=2).fit_transform(df_sector.iloc[:,4:])
    Principle=pd.DataFrame(Principle, columns=['P1','P2'])
    new_df=df_sector.iloc[:,:4]
    new_df[['P1','P2']]=Principle
    return new_df

def getCluster(df_sector):

#     clustering = SpectralClustering(n_clusters=3, assign_labels='discretize', random_state=0).fit(df_sector.iloc[:,4:]) # need to define n_cluster, 
#     clustering = OPTICS().fit(df_sector.iloc[:,4:]) # not need to define n_cluster, some interesting result, 
    # for optics, DBSCAN, Cluster labels for each point in the dataset given to fit(). 
    # Noisy samples and points which are not included in a leaf cluster of cluster_hierarchy_ are labeled as -1.
    clustering = DBSCAN().fit(df_sector.iloc[:,4:]) # result only one cluster
    return clustering.labels_.astype(str)
    
def checkGroupAgg(df, df_sector_cluster, by=['cluster','Sector'], func = ['max','min']):
    df_cluster = pd.concat([df_sector_cluster[by], df.iloc[:,2:]], axis=1)
    return df_cluster.groupby(by).agg(func).style.highlight_max(axis=0)

def groupcount(df_sector_cluster):
    df = df_sector_cluster[['cluster','Sector','ID']].groupby(['cluster','Sector']).agg('count').reset_index(drop=False)
    df.columns=['cluster','Sector','count']
    return df.sort_values(by=['cluster','count'], ascending=False)

def masking0row(df):
    df_data=df.iloc[:,3:]
    mask = (df_data != 0).sum(1)!=0
    print('Drop', len(df[-mask]['Subsector']), 'unrelative subsectors that contain only zero \n',df[-mask]['Subsector'], )
    return df[mask]

def plot_scatter(df_sector_cluster, style="cluster", hue="cluster", size = None, figsize = (5,5), if_ledgend= True):
    plt.figure(figsize=figsize)
    g= sns.scatterplot(data=df_sector_cluster, x="P1", y="P2", style=style, hue=hue, size = size, palette="viridis")
    if if_ledgend:
        plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)
    else:
        plt.legend([],[], frameon=False)
    plt.savefig('img/'+ 'scatter' +'.png')
    plt.show()
    
def plot_lm(df_sector_cluster, hue="cluster", figsize = (5,5), if_ledgend= True):
    plt.figure(figsize=figsize)
    g= sns.lmplot(data=df_sector_cluster, x="P1", y="P2", hue=hue, ci=None)
    if if_ledgend:
        plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)
    else:
        plt.legend([],[], frameon=False)
    plt.savefig('img/'+ 'lm' + '.png')
    plt.show()

def plotHeatmap(df):
    # Compute the correlation matrix
    corr = df.iloc[:,2:].corr()
    # Generate a mask for the upper triangle
    mask = np.triu(np.ones_like(corr, dtype=bool))
    # Set up the matplotlib figure
    f, ax = plt.subplots(figsize=(11, 9))
    # Generate a custom diverging colormap
    cmap = sns.diverging_palette(230, 20, as_cmap=True)
    # Draw the heatmap with the mask and correct aspect ratio
    sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
                square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
# df = airpolu.merge(GWP.drop(columns=['Total t CO2e']), on=['ID'], how='outer').fillna(0)
# df['Subsector_x']=df['Subsector_x'].astype('str') + " OR " + df['Subsector_y'].astype('str')
# df= df.drop(columns=['Subsector_y']).rename(columns={"Subsector_x": "Subsector"})
# df = df.merge(energy.drop(columns=['Total Energy TJ']), on=['ID'], how='outer').fillna(0)
# df['Subsector_x']=df['Subsector_x'].astype('str') + " OR " + df['Subsector_y'].astype('str')
# df= df.drop(columns=['Subsector_y']).rename(columns={"Subsector_x": "Subsector"})
# df.head(5)

# %%
df= GWP.drop(columns=['Total t CO2e'])
df = df.merge(energy.drop(columns=['Total Energy TJ']), on=['ID'], how='outer').fillna(0)
df['Subsector_x']=df['Subsector_x'].astype('str') + " OR " + df['Subsector_y'].astype('str')
df= df.drop(columns=['Subsector_y']).rename(columns={"Subsector_x": "Subsector"})
df
# Out:
#          ID                                          Subsector  CO2 t CO2e  \
# 0    1111B0                     Grain farming OR Grain farming   6080000.0
# 1    221100  Power generation and supply OR Power generatio...  25800000.0
# 2    1121A0  Cattle ranching and farming OR Cattle ranching...   1250000.0
# 3    1111A0                 Oilseed farming OR Oilseed farming   2150000.0
# 4    311111  Dog and cat food manufacturing OR Dog and cat ...   8100000.0
# ..      ...                                                ...         ...
# 423  S00900                   ROW Adjustment OR ROW Adjustment         0.0
# 424  813100  Religious organizations OR Religious organizat...         0.0
# 425  230201  Residential permanent site single- and multi-f...         0.0
# 426  S00401                                     Scrap OR Scrap         0.0
# 427  S00402  Used and Secondhand Goods OR Used and Secondha...         0.0
#
#      CH4 t CO2e  N2O t CO2e  Other GHGs t CO2e   Coal TJ  Nat Gas TJ  \
# 0             0     3360000           31800000       0.0     10400.0
# 1             0       70900             160000  232000.0     67900.0
# 2             0    10800000            6980000       0.0      1240.0
# 3             0       66600            7800000       0.0      3810.0
# 4             0           0                  0    7130.0    137000.0
# ..          ...         ...                ...       ...         ...
# 423           0           0                  0       0.0         0.0
# 424           0           0                  0       0.0         0.0
# 425           0           0                  0       0.0         0.0
# 426           0           0                  0       0.0         0.0
# 427           0           0                  0       0.0         0.0
#
#      Petrol  TJ  Bio_Waste TJ  NonFossElec TJ
# 0       80500.0           0.0         14800.0
# 1       11300.0           0.0          7450.0
# 2       17300.0           0.0          3580.0
# 3       28400.0           0.0          5610.0
# 4        8410.0        8120.0         42300.0
# ..          ...           ...             ...
# 423         0.0           0.0             0.0
# 424         0.0           0.0             0.0
# 425         0.0           0.0             0.0
# 426         0.0           0.0             0.0
# 427         0.0           0.0             0.0
#
# [428 rows x 11 columns]

# %%
scaler = MinMaxScaler(feature_range=(0,10))
df.iloc[:,2:] =scaler.fit_transform(df.iloc[:,2:])
df = masking0row(df).reset_index(drop=True)
print(df.shape)
# Out:
# Drop 18 unrelative subsectors that contain only zero
#  410           Death care services OR Death care services
# 411    Elementary and secondary schools OR Elementary...
# 412    General Federal Defense OR General Federal Def...
# 413    General Federal non-defense government industr...
# 414    Home health care services OR Home health care ...
# 415         Hunting and trapping OR Hunting and trapping
# 416    Museums, historical sites, zoos, and parks OR ...
# 417       Noncomparable Imports OR Noncomparable Imports
# 418    Nonresidential commercial and health care stru...
# 419    Nonresidential manufacturing structures OR Non...
# 420    Other nonresidential structures OR Other nonre...
# 421    Owner-Occupied Dwellings OR Owner-Occupied Dwe...
# 422             Private households OR Private households
# 423                     ROW Adjustment OR ROW Adjustment
# 424    Religious organizations OR Religious organizat...
# 425    Residential permanent site single- and multi-f...
# 426                                       Scrap OR Scrap
# 427    Used and Secondhand Goods OR Used and Secondha...
# Name: Subsector, dtype: object
# (410, 11)

# %%
# sns.pairplot(df.iloc[:,2:])

# %%
plotHeatmap(df)

# %%
sector = combineSector(df, df_sector=sector)
principle = tsneFind2Pinciple(sector)
sector_cluster=principle.copy()
sector_cluster['cluster']= getCluster(df_sector=sector)
plot_scatter(sector_cluster, style=None, hue='cluster', if_ledgend= True)
# Out:
# /usr/local/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(

# %%
plot_lm(sector_cluster, hue="cluster", if_ledgend= True)

# %%
for col in df.columns[2:]:
    print(col)
    col0mask = df[col]!=0
    
    tmp= sector_cluster[col0mask].copy()
    tmp['value']=df[col0mask][[col]]

    fig = plt.figure()
    sns.scatterplot(data=tmp[sector_cluster['cluster']=='-1'], 
                    x="P1", y="P2", size = 'value', palette="viridis")   
    plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)
    plt.savefig('img/'+ col +'.png')
    plt.show()
# Out:
# CO2 t CO2e
# CH4 t CO2e
# /var/folders/np/rttrhp2d3vq8g1yfhny3fc000000gn/T/ipykernel_12030/1834208469.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sns.scatterplot(data=tmp[sector_cluster['cluster']=='-1'],
# N2O t CO2e
# /var/folders/np/rttrhp2d3vq8g1yfhny3fc000000gn/T/ipykernel_12030/1834208469.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sns.scatterplot(data=tmp[sector_cluster['cluster']=='-1'],
# Other GHGs t CO2e
# /var/folders/np/rttrhp2d3vq8g1yfhny3fc000000gn/T/ipykernel_12030/1834208469.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sns.scatterplot(data=tmp[sector_cluster['cluster']=='-1'],
# Coal TJ
# /var/folders/np/rttrhp2d3vq8g1yfhny3fc000000gn/T/ipykernel_12030/1834208469.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sns.scatterplot(data=tmp[sector_cluster['cluster']=='-1'],
# Nat Gas TJ
# /var/folders/np/rttrhp2d3vq8g1yfhny3fc000000gn/T/ipykernel_12030/1834208469.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sns.scatterplot(data=tmp[sector_cluster['cluster']=='-1'],
# Petrol  TJ
# /var/folders/np/rttrhp2d3vq8g1yfhny3fc000000gn/T/ipykernel_12030/1834208469.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sns.scatterplot(data=tmp[sector_cluster['cluster']=='-1'],
# Bio_Waste TJ
# /var/folders/np/rttrhp2d3vq8g1yfhny3fc000000gn/T/ipykernel_12030/1834208469.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sns.scatterplot(data=tmp[sector_cluster['cluster']=='-1'],
# NonFossElec TJ
# /var/folders/np/rttrhp2d3vq8g1yfhny3fc000000gn/T/ipykernel_12030/1834208469.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sns.scatterplot(data=tmp[sector_cluster['cluster']=='-1'],

# %%
for col in df.columns[2:]:
    print(col)
    col0mask = df[col]!=0
    
    tmp= sector_cluster[col0mask].copy()
    tmp['value']=df[col0mask][[col]]

    fig = plt.figure()
    fig.subplots_adjust(hspace=0.4, wspace=0.4)
    ax = fig.add_subplot(1, 2, 1)
    sns.scatterplot(data=tmp[sector_cluster['cluster']=='-1'], 
                    x="P1", y="P2", size = 'value', palette="viridis", ax=ax)   
    ax = fig.add_subplot(1, 2, 2)
    sns.scatterplot(data=tmp[sector_cluster['cluster']!='-1'], 
                    x="P1", y="P2", style='cluster', hue='cluster', size = 'value', palette="viridis", ax=ax)   
    plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)
    plt.savefig('img/'+ col+'_comb.png')
    plt.show()
# Out:
# CO2 t CO2e
# CH4 t CO2e
# /var/folders/np/rttrhp2d3vq8g1yfhny3fc000000gn/T/ipykernel_12030/2849116093.py:11: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sns.scatterplot(data=tmp[sector_cluster['cluster']=='-1'],
# /var/folders/np/rttrhp2d3vq8g1yfhny3fc000000gn/T/ipykernel_12030/2849116093.py:14: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sns.scatterplot(data=tmp[sector_cluster['cluster']!='-1'],
# N2O t CO2e
# /var/folders/np/rttrhp2d3vq8g1yfhny3fc000000gn/T/ipykernel_12030/2849116093.py:11: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sns.scatterplot(data=tmp[sector_cluster['cluster']=='-1'],
# /var/folders/np/rttrhp2d3vq8g1yfhny3fc000000gn/T/ipykernel_12030/2849116093.py:14: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sns.scatterplot(data=tmp[sector_cluster['cluster']!='-1'],
# Other GHGs t CO2e
# /var/folders/np/rttrhp2d3vq8g1yfhny3fc000000gn/T/ipykernel_12030/2849116093.py:11: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sns.scatterplot(data=tmp[sector_cluster['cluster']=='-1'],
# /var/folders/np/rttrhp2d3vq8g1yfhny3fc000000gn/T/ipykernel_12030/2849116093.py:14: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sns.scatterplot(data=tmp[sector_cluster['cluster']!='-1'],
# Coal TJ
# /var/folders/np/rttrhp2d3vq8g1yfhny3fc000000gn/T/ipykernel_12030/2849116093.py:11: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sns.scatterplot(data=tmp[sector_cluster['cluster']=='-1'],
# /var/folders/np/rttrhp2d3vq8g1yfhny3fc000000gn/T/ipykernel_12030/2849116093.py:14: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sns.scatterplot(data=tmp[sector_cluster['cluster']!='-1'],
# Nat Gas TJ
# /var/folders/np/rttrhp2d3vq8g1yfhny3fc000000gn/T/ipykernel_12030/2849116093.py:11: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sns.scatterplot(data=tmp[sector_cluster['cluster']=='-1'],
# /var/folders/np/rttrhp2d3vq8g1yfhny3fc000000gn/T/ipykernel_12030/2849116093.py:14: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sns.scatterplot(data=tmp[sector_cluster['cluster']!='-1'],
# Petrol  TJ
# /var/folders/np/rttrhp2d3vq8g1yfhny3fc000000gn/T/ipykernel_12030/2849116093.py:11: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sns.scatterplot(data=tmp[sector_cluster['cluster']=='-1'],
# /var/folders/np/rttrhp2d3vq8g1yfhny3fc000000gn/T/ipykernel_12030/2849116093.py:14: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sns.scatterplot(data=tmp[sector_cluster['cluster']!='-1'],
# Bio_Waste TJ
# /var/folders/np/rttrhp2d3vq8g1yfhny3fc000000gn/T/ipykernel_12030/2849116093.py:11: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sns.scatterplot(data=tmp[sector_cluster['cluster']=='-1'],
# /var/folders/np/rttrhp2d3vq8g1yfhny3fc000000gn/T/ipykernel_12030/2849116093.py:14: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sns.scatterplot(data=tmp[sector_cluster['cluster']!='-1'],
# NonFossElec TJ
# /var/folders/np/rttrhp2d3vq8g1yfhny3fc000000gn/T/ipykernel_12030/2849116093.py:11: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sns.scatterplot(data=tmp[sector_cluster['cluster']=='-1'],
# /var/folders/np/rttrhp2d3vq8g1yfhny3fc000000gn/T/ipykernel_12030/2849116093.py:14: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sns.scatterplot(data=tmp[sector_cluster['cluster']!='-1'],

# %%
checkGroupAgg(df = energy, df_sector_cluster = sector_cluster,
             by=['cluster'], func = ['max','min'])
# Out:
# <style type="text/css">
# #T_dbcee_row0_col0, #T_dbcee_row0_col1, #T_dbcee_row0_col2, #T_dbcee_row0_col3, #T_dbcee_row0_col4, #T_dbcee_row0_col5, #T_dbcee_row0_col6, #T_dbcee_row0_col7, #T_dbcee_row0_col8, #T_dbcee_row0_col9, #T_dbcee_row0_col10, #T_dbcee_row0_col11, #T_dbcee_row1_col3, #T_dbcee_row1_col5, #T_dbcee_row1_col7, #T_dbcee_row1_col9 {
#   background-color: yellow;
# }
# </style>
# <table id="T_dbcee_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" colspan="2">Total Energy TJ</th>
#       <th class="col_heading level0 col2" colspan="2">Coal TJ</th>
#       <th class="col_heading level0 col4" colspan="2">Nat Gas TJ</th>
#       <th class="col_heading level0 col6" colspan="2">Petrol  TJ</th>
#       <th class="col_heading level0 col8" colspan="2">Bio_Waste TJ</th>
#       <th class="col_heading level0 col10" colspan="2">NonFossElec TJ</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th class="col_heading level1 col0" >max</th>
#       <th class="col_heading level1 col1" >min</th>
#       <th class="col_heading level1 col2" >max</th>
#       <th class="col_heading level1 col3" >min</th>
#       <th class="col_heading level1 col4" >max</th>
#       <th class="col_heading level1 col5" >min</th>
#       <th class="col_heading level1 col6" >max</th>
#       <th class="col_heading level1 col7" >min</th>
#       <th class="col_heading level1 col8" >max</th>
#       <th class="col_heading level1 col9" >min</th>
#       <th class="col_heading level1 col10" >max</th>
#       <th class="col_heading level1 col11" >min</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >cluster</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dbcee_level0_row0" class="row_heading level0 row0" >-1</th>
#       <td id="T_dbcee_row0_col0" class="data row0 col0" >319000.000000</td>
#       <td id="T_dbcee_row0_col1" class="data row0 col1" >1100.000000</td>
#       <td id="T_dbcee_row0_col2" class="data row0 col2" >232000.000000</td>
#       <td id="T_dbcee_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_dbcee_row0_col4" class="data row0 col4" >137000.000000</td>
#       <td id="T_dbcee_row0_col5" class="data row0 col5" >0.000000</td>
#       <td id="T_dbcee_row0_col6" class="data row0 col6" >80500.000000</td>
#       <td id="T_dbcee_row0_col7" class="data row0 col7" >0.000000</td>
#       <td id="T_dbcee_row0_col8" class="data row0 col8" >18100.000000</td>
#       <td id="T_dbcee_row0_col9" class="data row0 col9" >0.000000</td>
#       <td id="T_dbcee_row0_col10" class="data row0 col10" >42300.000000</td>
#       <td id="T_dbcee_row0_col11" class="data row0 col11" >150.000000</td>
#     </tr>
#     <tr>
#       <th id="T_dbcee_level0_row1" class="row_heading level0 row1" >0</th>
#       <td id="T_dbcee_row1_col0" class="data row1 col0" >25700.000000</td>
#       <td id="T_dbcee_row1_col1" class="data row1 col1" >0.003000</td>
#       <td id="T_dbcee_row1_col2" class="data row1 col2" >955.000000</td>
#       <td id="T_dbcee_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_dbcee_row1_col4" class="data row1 col4" >18100.000000</td>
#       <td id="T_dbcee_row1_col5" class="data row1 col5" >0.000000</td>
#       <td id="T_dbcee_row1_col6" class="data row1 col6" >17300.000000</td>
#       <td id="T_dbcee_row1_col7" class="data row1 col7" >0.000000</td>
#       <td id="T_dbcee_row1_col8" class="data row1 col8" >1180.000000</td>
#       <td id="T_dbcee_row1_col9" class="data row1 col9" >0.000000</td>
#       <td id="T_dbcee_row1_col10" class="data row1 col10" >4880.000000</td>
#       <td id="T_dbcee_row1_col11" class="data row1 col11" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
checkGroupAgg(df = energy, df_sector_cluster = sector_cluster,
             by=['cluster','Sector'], func = ['max','min'])
# Out:
# <style type="text/css">
# #T_6d551_row0_col0, #T_6d551_row0_col2, #T_6d551_row0_col6, #T_6d551_row1_col8, #T_6d551_row2_col7, #T_6d551_row5_col1, #T_6d551_row5_col3, #T_6d551_row5_col4, #T_6d551_row5_col5, #T_6d551_row5_col9, #T_6d551_row5_col10, #T_6d551_row5_col11 {
#   background-color: yellow;
# }
# </style>
# <table id="T_6d551_">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" colspan="2">Total Energy TJ</th>
#       <th class="col_heading level0 col2" colspan="2">Coal TJ</th>
#       <th class="col_heading level0 col4" colspan="2">Nat Gas TJ</th>
#       <th class="col_heading level0 col6" colspan="2">Petrol  TJ</th>
#       <th class="col_heading level0 col8" colspan="2">Bio_Waste TJ</th>
#       <th class="col_heading level0 col10" colspan="2">NonFossElec TJ</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level1" >&nbsp;</th>
#       <th class="col_heading level1 col0" >max</th>
#       <th class="col_heading level1 col1" >min</th>
#       <th class="col_heading level1 col2" >max</th>
#       <th class="col_heading level1 col3" >min</th>
#       <th class="col_heading level1 col4" >max</th>
#       <th class="col_heading level1 col5" >min</th>
#       <th class="col_heading level1 col6" >max</th>
#       <th class="col_heading level1 col7" >min</th>
#       <th class="col_heading level1 col8" >max</th>
#       <th class="col_heading level1 col9" >min</th>
#       <th class="col_heading level1 col10" >max</th>
#       <th class="col_heading level1 col11" >min</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >cluster</th>
#       <th class="index_name level1" >Sector</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6d551_level0_row0" class="row_heading level0 row0" rowspan="7">-1</th>
#       <th id="T_6d551_level1_row0" class="row_heading level1 row0" >Agriculture, Forestry, Fishing and Hunting</th>
#       <td id="T_6d551_row0_col0" class="data row0 col0" >319000.000000</td>
#       <td id="T_6d551_row0_col1" class="data row0 col1" >31300.000000</td>
#       <td id="T_6d551_row0_col2" class="data row0 col2" >232000.000000</td>
#       <td id="T_6d551_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_6d551_row0_col4" class="data row0 col4" >67900.000000</td>
#       <td id="T_6d551_row0_col5" class="data row0 col5" >0.000000</td>
#       <td id="T_6d551_row0_col6" class="data row0 col6" >80500.000000</td>
#       <td id="T_6d551_row0_col7" class="data row0 col7" >11300.000000</td>
#       <td id="T_6d551_row0_col8" class="data row0 col8" >0.000000</td>
#       <td id="T_6d551_row0_col9" class="data row0 col9" >0.000000</td>
#       <td id="T_6d551_row0_col10" class="data row0 col10" >14800.000000</td>
#       <td id="T_6d551_row0_col11" class="data row0 col11" >509.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6d551_level1_row1" class="row_heading level1 row1" >Manufacturing</th>
#       <td id="T_6d551_row1_col0" class="data row1 col0" >46500.000000</td>
#       <td id="T_6d551_row1_col1" class="data row1 col1" >1290.000000</td>
#       <td id="T_6d551_row1_col2" class="data row1 col2" >26000.000000</td>
#       <td id="T_6d551_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_6d551_row1_col4" class="data row1 col4" >26800.000000</td>
#       <td id="T_6d551_row1_col5" class="data row1 col5" >411.000000</td>
#       <td id="T_6d551_row1_col6" class="data row1 col6" >25300.000000</td>
#       <td id="T_6d551_row1_col7" class="data row1 col7" >0.000000</td>
#       <td id="T_6d551_row1_col8" class="data row1 col8" >18100.000000</td>
#       <td id="T_6d551_row1_col9" class="data row1 col9" >0.000000</td>
#       <td id="T_6d551_row1_col10" class="data row1 col10" >4800.000000</td>
#       <td id="T_6d551_row1_col11" class="data row1 col11" >150.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6d551_level1_row2" class="row_heading level1 row2" >Mining, Quarrying, and Oil and Gas Extraction</th>
#       <td id="T_6d551_row2_col0" class="data row2 col0" >37800.000000</td>
#       <td id="T_6d551_row2_col1" class="data row2 col1" >37800.000000</td>
#       <td id="T_6d551_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_6d551_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_6d551_row2_col4" class="data row2 col4" >3810.000000</td>
#       <td id="T_6d551_row2_col5" class="data row2 col5" >3810.000000</td>
#       <td id="T_6d551_row2_col6" class="data row2 col6" >28400.000000</td>
#       <td id="T_6d551_row2_col7" class="data row2 col7" >28400.000000</td>
#       <td id="T_6d551_row2_col8" class="data row2 col8" >0.000000</td>
#       <td id="T_6d551_row2_col9" class="data row2 col9" >0.000000</td>
#       <td id="T_6d551_row2_col10" class="data row2 col10" >5610.000000</td>
#       <td id="T_6d551_row2_col11" class="data row2 col11" >5610.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6d551_level1_row3" class="row_heading level1 row3" >Real Estate and Rental and Leasing</th>
#       <td id="T_6d551_row3_col0" class="data row3 col0" >1100.000000</td>
#       <td id="T_6d551_row3_col1" class="data row3 col1" >1100.000000</td>
#       <td id="T_6d551_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_6d551_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_6d551_row3_col4" class="data row3 col4" >105.000000</td>
#       <td id="T_6d551_row3_col5" class="data row3 col5" >105.000000</td>
#       <td id="T_6d551_row3_col6" class="data row3 col6" >56.800000</td>
#       <td id="T_6d551_row3_col7" class="data row3 col7" >56.800000</td>
#       <td id="T_6d551_row3_col8" class="data row3 col8" >762.000000</td>
#       <td id="T_6d551_row3_col9" class="data row3 col9" >762.000000</td>
#       <td id="T_6d551_row3_col10" class="data row3 col10" >177.000000</td>
#       <td id="T_6d551_row3_col11" class="data row3 col11" >177.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6d551_level1_row4" class="row_heading level1 row4" >Transportation and Warehousing</th>
#       <td id="T_6d551_row4_col0" class="data row4 col0" >35000.000000</td>
#       <td id="T_6d551_row4_col1" class="data row4 col1" >16000.000000</td>
#       <td id="T_6d551_row4_col2" class="data row4 col2" >17600.000000</td>
#       <td id="T_6d551_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_6d551_row4_col4" class="data row4 col4" >8110.000000</td>
#       <td id="T_6d551_row4_col5" class="data row4 col5" >4270.000000</td>
#       <td id="T_6d551_row4_col6" class="data row4 col6" >2310.000000</td>
#       <td id="T_6d551_row4_col7" class="data row4 col7" >135.000000</td>
#       <td id="T_6d551_row4_col8" class="data row4 col8" >17300.000000</td>
#       <td id="T_6d551_row4_col9" class="data row4 col9" >123.000000</td>
#       <td id="T_6d551_row4_col10" class="data row4 col10" >11200.000000</td>
#       <td id="T_6d551_row4_col11" class="data row4 col11" >3550.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6d551_level1_row5" class="row_heading level1 row5" >Utilities</th>
#       <td id="T_6d551_row5_col0" class="data row5 col0" >203000.000000</td>
#       <td id="T_6d551_row5_col1" class="data row5 col1" >203000.000000</td>
#       <td id="T_6d551_row5_col2" class="data row5 col2" >7130.000000</td>
#       <td id="T_6d551_row5_col3" class="data row5 col3" >7130.000000</td>
#       <td id="T_6d551_row5_col4" class="data row5 col4" >137000.000000</td>
#       <td id="T_6d551_row5_col5" class="data row5 col5" >137000.000000</td>
#       <td id="T_6d551_row5_col6" class="data row5 col6" >8410.000000</td>

# %%
groupcount(sector_cluster)
# Out:
#    cluster                                             Sector  count
# 17       0                                      Manufacturing    263
# 9        0         Agriculture, Forestry, Fishing and Hunting     14
# 15       0                                        Information     14
# 20       0   Professional, Scientific, and Technical Services     14
# 18       0      Mining, Quarrying, and Oil and Gas Extraction     10
# 19       0      Other Services (except Public Administration)     10
# 8        0  Administrative and Support and Waste Managemen...      9
# 10       0                Arts, Entertainment, and Recreation      8
# 14       0                  Health Care and Social Assistance      7
# 22       0                     Transportation and Warehousing      7
# 13       0                              Finance and Insurance      6
# 21       0                 Real Estate and Rental and Leasing      5
# 7        0                    Accommodation and Food Services      3
# 11       0                                       Construction      3
# 12       0                               Educational Services      2
# 23       0                                          Utilities      2
# 16       0            Management of Companies and Enterprises      1
# 1       -1                                      Manufacturing     16
# 0       -1         Agriculture, Forestry, Fishing and Hunting      4
# 4       -1                     Transportation and Warehousing      3
# 2       -1      Mining, Quarrying, and Oil and Gas Extraction      1
# 3       -1                 Real Estate and Rental and Leasing      1
# 5       -1                                          Utilities      1
# 6       -1                                    Wholesale Trade      1

# %%
sector_cluster.sort_values(by="cluster")[['Sector', 'Subsector', 'cluster']].to_csv('cluster_TSNE.csv')

# %%
sector_cluster.to_csv('PC_w_cluster.csv', index=False)
